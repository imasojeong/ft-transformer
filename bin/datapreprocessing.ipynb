# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

EQ_df = pd.read_csv('C:/Users/sojeong/Desktop/revisiting-models/data/EQ/EQ.csv')

print(EQ_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 62 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ck_oo_numberOfPrivateMethods         324 non-null    int64
#  1   LDHH_lcom                            324 non-null    float64
#  2   LDHH_fanIn                           324 non-null    float64
#  3   numberOfNonTrivialBugsFoundUntil:    324 non-null    int64
#  4   WCHU_numberOfPublicAttributes        324 non-null    float64
#  5   WCHU_numberOfAttributes              324 non-null    float64
#  6   CvsWEntropy                          324 non-null    float64
#  7   LDHH_numberOfPublicMethods           324 non-null    float64
#  8   WCHU_fanIn                           324 non-null    float64
#  9   LDHH_numberOfPrivateAttributes       324 non-null    float64
#  10  CvsEntropy                           324 non-null    float64
# ...

# %%
EQ_df.isnull().sum()
# Out:
# ck_oo_numberOfPrivateMethods         0
# LDHH_lcom                            0
# LDHH_fanIn                           0
# numberOfNonTrivialBugsFoundUntil:    0
# WCHU_numberOfPublicAttributes        0
#                                     ..
# LDHH_cbo                             0
# WCHU_numberOfLinesOfCode             0
# CvsExpEntropy                        0
# LDHH_numberOfMethods                 0
# class                                0
# Length: 62, dtype: int64

# %% [markdown]
# 정규화

# %%
# from sklearn.preprocessing import MinMaxScaler

# EQ_x_df = pd.read_csv('C:/Users/sojeong/Desktop/revisiting-models/data/EQ/x.csv')
# # x = EQ_x_df.values.astype(float)
# x_scaled = MinMaxScaler.fit_transform(x)

# EQ_x_df = pd.DataFrame(x_scaled, columns=EQ_df.columns)
# EQ_x_df

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# scaler.fit(EQ_df)
# iris_scaled = scaler.transform(EQ_df)

# # 역시나 transform() 결과가 ndarray라 DataFrame으로 바꿔준다.
# df_scaled = pd.DataFrame(iris_scaled, columns=EQ.feature_names)
# print('[최솟값]')
# print(df_scaled.min())
# print('\n[최댓값]')
# print(df_scaled.max())

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
EQ_x_df = pd.read_csv('C:/Users/sojeong/Desktop/revisiting-models/data/EQ/x.csv')

scaler = MinMaxScaler() 
EQ_x_df[:] = scaler.fit_transform(EQ_x_df[:])

EQ_x_df
# scaler.fit(EQ_x_df)
# EQ_scaled = scaler.transform(EQ_x_df)

# EQ_df_scaled = pd.DataFrame(data=EQ_scaled, columns=EQ_df.feature_names)
# print('feature들의 최소 값')
# print(EQ_df_scaled.min())
# print('\nfeature들의 최대 값')
# print(EQ_df_scaled.max())
# Out:
#      ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0                        0.061224   0.103385    0.109109
# 1                        0.755102   0.350828    0.203100
# 2                        0.061224   0.060034    0.390443
# 3                        0.204082   0.229014    0.230388
# 4                        0.020408   0.054798    0.000000
# ..                            ...        ...         ...
# 319                      0.020408   0.000000    0.000000
# 320                      0.020408   0.000000    0.000000
# 321                      0.040816   0.188058    0.769996
# 322                      0.000000   0.000000    0.000000
# 323                      0.000000   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                             0.056338                       0.000000
# 1                             1.000000                       0.000000
# ...
